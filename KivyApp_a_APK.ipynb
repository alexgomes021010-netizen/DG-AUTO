# %% [markdown]
# <a href="https://colab.research.google.com/github/alexgomes021010-netizen/DG-AUTO/blob/main/KivyApp_a_APK.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Convertir la aplicación Python en APK**

# %% [markdown]
# Como se trata de un sistema basado en Linux, ahora lo único que se requiere es instalar las dependencias e iniciar el proceso.
#
# Antes de ejecutar las celdas, asegúrese de cargar el código de su aplicación en el cuaderno de colab y, después de ejecutar el comando bulldozer init, asegúrese de editar el archivo de especificaciones generado y nada más.
#
# *Fuente:* *https://towardsdatascience.com/3-ways-to-convert-python-app-into-apk-77f4c9cd55af*

# %%
# !pip install buildozer
# Out:
# Collecting buildozer
#   Downloading buildozer-1.6.0-py3-none-any.whl.metadata (159 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.3/159.3 kB 3.6 MB/s eta 0:00:00
# Requirement already satisfied: pexpect in /usr/local/lib/python3.13/dist-packages (from buildozer) (4.9.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.13/dist-packages (from buildozer) (26.3)
# Collecting cython<3.0 (from buildozer)
#   Downloading Cython-0.29.37-py2.py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.13/dist-packages (from pexpect->buildozer) (0.7.0)
# Downloading buildozer-1.6.0-py3-none-any.whl (92 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.7/92.7 kB 6.6 MB/s eta 0:00:00
# Downloading Cython-0.29.37-py2.py3-none-any.whl (989 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 989.5/989.5 kB 21.5 MB/s eta 0:00:00
# Installing collected packages: cython, buildozer
#   Attempting uninstall: cython
#     Found existing installation: Cython 3.0.12
#     Uninstalling Cython-3.0.12:
#       Successfully uninstalled Cython-3.0.12
# Successfully installed buildozer-1.6.0 cython-0.29.37

# %%
# !pip install cython==0.29.19
# Out:
# Collecting cython==0.29.19
#   Downloading Cython-0.29.19-py2.py3-none-any.whl.metadata (2.6 kB)
# Downloading Cython-0.29.19-py2.py3-none-any.whl (971 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 971.9/971.9 kB 12.8 MB/s eta 0:00:00
# Installing collected packages: cython
#   Attempting uninstall: cython
#     Found existing installation: Cython 0.29.37
#     Uninstalling Cython-0.29.37:
#       Successfully uninstalled Cython-0.29.37
# Successfully installed cython-0.29.19

# %%
# !sudo apt-get install -y \
    python3-pip \
    build-essential \
    git \
    python3 \
    python3-dev \
    ffmpeg \
    libsdl2-dev \
    libsdl2-image-dev \
    libsdl2-mixer-dev \
    libsdl2-ttf-dev \
    libportmidi-dev \
    libswscale-dev \
    libavformat-dev \
    libavcodec-dev \
    zlib1g-dev
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# build-essential is already the newest version (12.10ubuntu1).
# git is already the newest version (1:2.43.0-1ubuntu7.3).
# python3 is already the newest version (3.12.3-0ubuntu2.1).
# python3 set to manually installed.
# ffmpeg is already the newest version (7:6.1.1-3ubuntu5).
# zlib1g-dev is already the newest version (1:1.3.dfsg-3.1ubuntu2.2).
# zlib1g-dev set to manually installed.
# The following additional packages will be installed:
#   gir1.2-ibus-1.0 javascript-common libasound2-dev libavutil-dev libdbus-1-dev
#   libdecor-0-dev libdrm-dev libdrm-nouveau2 libdrm-radeon1 libegl-dev
#   libfluidsynth-dev libfluidsynth3 libgbm-dev libgl-dev libgles-dev libgles1
#   libglx-dev libgraphite2-dev libharfbuzz-cairo0 libharfbuzz-dev
#   libharfbuzz-icu0 libharfbuzz-subset0 libibus-1.0-5 libibus-1.0-dev
#   libinstpatch-1.0-2 libinstpatch-dev libjack-dev libjack0 libjs-sphinxdoc
#   libjs-underscore libmodplug-dev libmodplug1 libopusfile-dev libopusfile0
#   libpciaccess-dev libpipewire-0.3-0t64 libpipewire-0.3-common
#   libpipewire-0.3-dev libportmidi0 libpulse-dev libpulse-mainloop-glib0
#   libsamplerate0-dev libsdl2-image-2.0-0 libsdl2-mixer-2.0-0 libsdl2-ttf-2.0-0
#   libsndio-dev libspa-0.2-dev libspa-0.2-modules libswresample-dev
#   libsystemd-dev libudev-dev libwayland-bin libwayland-dev libwayland-server0
#   libwebrtc-audio-processing1 libxcursor-dev libxfixes-dev libxi-dev
#   libxinerama-dev libxkbcommon-dev libxrandr-dev libxt-dev libxv-dev
#   libxxf86vm-dev python3-wheel python3.12-dev timgm6mb-soundfont
# Suggested packages:
#   apache2 | lighttpd | httpd libasound2-doc libgraphite2-utils jackd1 pipewire
#   pipewire-doc libwayland-doc libxt-doc fluid-soundfont-gm
# The following packages will be REMOVED:
#   libjack-jackd2-0
# The following NEW packages will be installed:
#   gir1.2-ibus-1.0 javascript-common libasound2-dev libavcodec-dev
#   libavformat-dev libavutil-dev libdbus-1-dev libdecor-0-dev libdrm-dev
#   libdrm-nouveau2 libdrm-radeon1 libegl-dev libfluidsynth-dev libfluidsynth3
#   libgbm-dev libgl-dev libgles-dev libgles1 libglx-dev libgraphite2-dev
#   libharfbuzz-cairo0 libharfbuzz-dev libharfbuzz-icu0 libharfbuzz-subset0
#   libibus-1.0-5 libibus-1.0-dev libinstpatch-1.0-2 libinstpatch-dev
#   libjack-dev libjack0 libjs-sphinxdoc libjs-underscore libmodplug-dev
#   libmodplug1 libopusfile-dev libopusfile0 libpciaccess-dev
#   libpipewire-0.3-0t64 libpipewire-0.3-common libpipewire-0.3-dev
#   libportmidi-dev libportmidi0 libpulse-dev libpulse-mainloop-glib0
#   libsamplerate0-dev libsdl2-dev libsdl2-image-2.0-0 libsdl2-image-dev
#   libsdl2-mixer-2.0-0 libsdl2-mixer-dev libsdl2-ttf-2.0-0 libsdl2-ttf-dev
#   libsndio-dev libspa-0.2-dev libspa-0.2-modules libswresample-dev
#   libswscale-dev libsystemd-dev libudev-dev libwayland-bin libwayland-dev
#   libwayland-server0 libwebrtc-audio-processing1 libxcursor-dev libxfixes-dev
#   libxi-dev libxinerama-dev libxkbcommon-dev libxrandr-dev libxt-dev libxv-dev
#   libxxf86vm-dev python3-dev python3-pip python3-wheel python3.12-dev
#   timgm6mb-soundfont
# 0 upgraded, 77 newly installed, 1 to remove and 11 not upgraded.
# Need to get 24.8 MB of archives.
# After this operation, 89.6 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu noble/universe amd64 libjack0 amd64 1:0.126.0-2build3 [101 kB]
# Get:2 http://archive.ubuntu.com/ubuntu noble/main amd64 libibus-1.0-5 amd64 1.5.29-2 [181 kB]
# Get:3 http://archive.ubuntu.com/ubuntu noble/main amd64 gir1.2-ibus-1.0 amd64 1.5.29-2 [86.3 kB]
# Get:4 http://archive.ubuntu.com/ubuntu noble/main amd64 javascript-common all 11+nmu1 [5,936 B]
# Get:5 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libasound2-dev amd64 1.2.11-1ubuntu0.3 [115 kB]
# Get:6 http://archive.ubuntu.com/ubuntu noble/universe amd64 libavutil-dev amd64 7:6.1.1-3ubuntu5 [547 kB]
# Get:7 http://archive.ubuntu.com/ubuntu noble/universe amd64 libswresample-dev amd64 7:6.1.1-3ubuntu5 [79.7 kB]
# Get:8 http://archive.ubuntu.com/ubuntu noble/universe amd64 libavcodec-dev amd64 7:6.1.1-3ubuntu5 [6,504 kB]
# Get:9 http://archive.ubuntu.com/ubuntu noble/universe amd64 libavformat-dev amd64 7:6.1.1-3ubuntu5 [1,398 kB]
# Get:10 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libdbus-1-dev amd64 1.14.10-4ubuntu4.1 [190 kB]
# Get:11 http://archive.ubuntu.com/ubuntu noble/main amd64 libwayland-server0 amd64 1.22.0-2.1build1 [33.9 kB]
# Get:12 http://archive.ubuntu.com/ubuntu noble/main amd64 libwayland-bin amd64 1.22.0-2.1build1 [20.6 kB]
# Get:13 http://archive.ubuntu.com/ubuntu noble/main amd64 libwayland-dev amd64 1.22.0-2.1build1 [71.3 kB]
# Get:14 http://archive.ubuntu.com/ubuntu noble/main amd64 libdecor-0-dev amd64 0.2.2-1build2 [5,726 B]
# Get:15 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libdrm-radeon1 amd64 2.4.125-1ubuntu0.1~24.04.2 [20.8 kB]
# Get:16 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libdrm-nouveau2 amd64 2.4.125-1ubuntu0.1~24.04.2 [17.6 kB]
# Get:17 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libpciaccess-dev amd64 0.17-3ubuntu0.24.04.2 [22.0 kB]
# Get:18 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libdrm-dev amd64 2.4.125-1ubuntu0.1~24.04.2 [314 kB]
# Get:19 http://archive.ubuntu.com/ubuntu noble/main amd64 libglx-dev amd64 1.7.0-1build1 [14.2 kB]
# Get:20 http://archive.ubuntu.com/ubuntu noble/main amd64 libgl-dev amd64 1.7.0-1build1 [102 kB]
# Get:21 http://archive.ubuntu.com/ubuntu noble/main amd64 libegl-dev amd64 1.7.0-1build1 [18.2 kB]
# Get:22 http://archive.ubuntu.com/ubuntu noble/universe amd64 libinstpatch-1.0-2 amd64 1.1.6-1build2 [251 kB]
# Get:23 http://archive.ubuntu.com/ubuntu noble/main amd64 libwebrtc-audio-processing1 amd64 0.3.1-0ubuntu6 [290 kB]
# Get:24 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libspa-0.2-modules amd64 1.0.5-1ubuntu3.3 [628 kB]
# Get:25 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libpipewire-0.3-0t64 amd64 1.0.5-1ubuntu3.3 [252 kB]
# Get:26 http://archive.ubuntu.com/ubuntu noble/universe amd64 timgm6mb-soundfont all 1.3-5 [5,427 kB]
# Get:27 http://archive.ubuntu.com/ubuntu noble/universe amd64 libfluidsynth3 amd64 2.3.4-1build3 [249 kB]
# Get:28 http://archive.ubuntu.com/ubuntu noble/universe amd64 libinstpatch-dev amd64 1.1.6-1build2 [55.6 kB]
# Get:29 http://archive.ubuntu.com/ubuntu noble/universe amd64 libjack-dev amd64 1:0.126.0-2build3 [140 kB]
# Get:30 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libspa-0.2-dev amd64 1.0.5-1ubuntu3.3 [109 kB]
# Get:31 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libpipewire-0.3-dev amd64 1.0.5-1ubuntu3.3 [53.3 kB]
# Get:32 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libpulse-mainloop-glib0 amd64 1:16.1+dfsg1-2ubuntu10.1 [12.2 kB]
# Get:33 http://archive.ubuntu.com/ubuntu noble-updates/universe amd64 libpulse-dev amd64 1:16.1+dfsg1-2ubuntu10.1 [75.6 kB]
# Get:34 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libgbm-dev amd64 25.2.8-0ubuntu0.24.04.2 [12.8 kB]
# Get:35 http://archive.ubuntu.com/ubuntu noble/main amd64 libgles1 amd64 1.7.0-1build1 [11.6 kB]
# Get:36 http://archive.ubuntu.com/ubuntu noble/main amd64 libgles-dev amd64 1.7.0-1build1 [50.5 kB]
# Get:37 http://archive.ubuntu.com/ubuntu noble/universe amd64 libibus-1.0-dev amd64 1.5.29-2 [187 kB]
# Get:38 http://archive.ubuntu.com/ubuntu noble/main amd64 libsamplerate0-dev amd64 0.2.2-4build1 [61.5 kB]
# Get:39 http://archive.ubuntu.com/ubuntu noble/universe amd64 libsndio-dev amd64 1.9.0-0.3build3 [17.7 kB]
# Get:40 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libudev-dev amd64 255.4-1ubuntu8.17 [22.0 kB]
# Get:41 http://archive.ubuntu.com/ubuntu noble/main amd64 libxfixes-dev amd64 1:6.0.0-2build1 [12.1 kB]
# Get:42 http://archive.ubuntu.com/ubuntu noble/main amd64 libxcursor-dev amd64 1:1.2.1-1build1 [31.8 kB]
# Get:43 http://archive.ubuntu.com/ubuntu noble/main amd64 libxi-dev amd64 2:1.8.1-1build1 [194 kB]
# Get:44 http://archive.ubuntu.com/ubuntu noble/main amd64 libxinerama-dev amd64 2:1.1.4-3build1 [7,988 B]
# Get:45 http://archive.ubuntu.com/ubuntu noble/main amd64 libxkbcommon-dev amd64 1.6.0-1build1 [56.3 kB]
# Get:46 http://archive.ubuntu.com/ubuntu noble/main amd64 libxrandr-dev amd64 2:1.5.2-2build1 [26.4 kB]
# Get:47 http://archive.ubuntu.com/ubuntu noble/main amd64 libxt-dev amd64 1:1.2.1-1.2build1 [394 kB]
# Get:48 http://archive.ubuntu.com/ubuntu noble/main amd64 libxv-dev amd64 2:1.0.11-1.1build1 [33.3 kB]
# Get:49 http://archive.ubuntu.com/ubuntu noble/main amd64 libxxf86vm-dev amd64 1:1.1.4-1build4 [13.8 kB]
# Get:50 http://archive.ubuntu.com/ubuntu noble-updates/universe amd64 libsdl2-dev amd64 2.30.0+dfsg-1ubuntu3.1 [1,141 kB]
# Get:51 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libsystemd-dev amd64 255.4-1ubuntu8.17 [1,239 kB]
# Get:52 http://archive.ubuntu.com/ubuntu noble/universe amd64 libfluidsynth-dev amd64 2.3.4-1build3 [39.4 kB]
# Get:53 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libgraphite2-dev amd64 1.3.14-2ubuntu0.24.04.1 [14.7 kB]
# Get:54 http://archive.ubuntu.com/ubuntu noble/main amd64 libharfbuzz-cairo0 amd64 8.3.0-2build2 [26.2 kB]
# Get:55 http://archive.ubuntu.com/ubuntu noble/main amd64 libharfbuzz-icu0 amd64 8.3.0-2build2 [13.3 kB]
# Get:56 http://archive.ubuntu.com/ubuntu noble/main amd64 libharfbuzz-subset0 amd64 8.3.0-2build2 [448 kB]
# Get:57 http://archive.ubuntu.com/ubuntu noble/main amd64 libharfbuzz-dev amd64 8.3.0-2build2 [142 kB]
# Get:58 http://archive.ubuntu.com/ubuntu noble/main amd64 libjs-underscore all 1.13.4~dfsg+~1.11.4-3 [118 kB]
# Get:59 http://archive.ubuntu.com/ubuntu noble/main amd64 libjs-sphinxdoc all 7.2.6-6 [149 kB]
# Get:60 http://archive.ubuntu.com/ubuntu noble/universe amd64 libmodplug1 amd64 1:0.8.9.0-3build1 [166 kB]
# Get:61 http://archive.ubuntu.com/ubuntu noble/universe amd64 libmodplug-dev amd64 1:0.8.9.0-3build1 [14.9 kB]
# Get:62 http://archive.ubuntu.com/ubuntu noble/universe amd64 libopusfile0 amd64 0.12-4build3 [44.7 kB]
# Get:63 http://archive.ubuntu.com/ubuntu noble/universe amd64 libopusfile-dev amd64 0.12-4build3 [63.1 kB]
# Get:64 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libpipewire-0.3-common all 1.0.5-1ubuntu3.3 [19.5 kB]
# Get:65 http://archive.ubuntu.com/ubuntu noble/universe amd64 libportmidi0 amd64 1:217-6.1build3 [18.1 kB]
# Get:66 http://archive.ubuntu.com/ubuntu noble/universe amd64 libportmidi-dev amd64 1:217-6.1build3 [54.7 kB]
# Get:67 http://archive.ubuntu.com/ubuntu noble/universe amd64 libsdl2-image-2.0-0 amd64 2.8.2+dfsg-1build2 [65.1 kB]
# Get:68 http://archive.ubuntu.com/ubuntu noble/universe amd64 libsdl2-image-dev amd64 2.8.2+dfsg-1build2 [77.1 kB]
# Get:69 http://archive.ubuntu.com/ubuntu noble/universe amd64 libsdl2-mixer-2.0-0 amd64 2.8.0+dfsg-1build3 [81.8 kB]
# Get:70 http://archive.ubuntu.com/ubuntu noble/universe amd64 libsdl2-mixer-dev amd64 2.8.0+dfsg-1build3 [116 kB]
# Get:71 http://archive.ubuntu.com/ubuntu noble/universe amd64 libsdl2-ttf-2.0-0 amd64 2.22.0+dfsg-1 [35.7 kB]
# Get:72 http://archive.ubuntu.com/ubuntu noble/universe amd64 libsdl2-ttf-dev amd64 2.22.0+dfsg-1 [45.8 kB]
# Get:73 http://archive.ubuntu.com/ubuntu noble/universe amd64 libswscale-dev amd64 7:6.1.1-3ubuntu5 [224 kB]
# Get:74 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 python3.12-dev amd64 3.12.3-1ubuntu0.16 [498 kB]
# Get:75 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 python3-dev amd64 3.12.3-0ubuntu2.1 [26.7 kB]
# Get:76 http://archive.ubuntu.com/ubuntu noble/universe amd64 python3-wheel all 0.42.0-2 [53.1 kB]
# Get:77 http://archive.ubuntu.com/ubuntu noble-updates/universe amd64 python3-pip all 24.0+dfsg-1ubuntu1.3 [1,320 kB]
# Fetched 24.8 MB in 2s (10.3 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 79, <STDIN> line 77.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# dpkg: libjack-jackd2-0:amd64: dependency problems, but removing anyway as you requested:
#  libavdevice60:amd64 depends on libjack-jackd2-0 (>= 1.9.10+20150825) | libjack-0.125; however:
#   Package libjack-jackd2-0:amd64 is to be removed.
#   Package libjack-0.125 is not installed.
#   Package libjack-jackd2-0:amd64 which provides libjack-0.125 is to be removed.
#  libavdevice60:amd64 depends on libjack-jackd2-0 (>= 1.9.10+20150825) | libjack-0.125; however:
#   Package libjack-jackd2-0:amd64 is to be removed.
#   Package libjack-0.125 is not installed.
#   Package libjack-jackd2-0:amd64 which provides libjack-0.125 is to be removed.
#
# (Reading database ... 122797 files and directories currently installed.)
# Removing libjack-jackd2-0:amd64 (1.9.21~dfsg-3ubuntu3) ...
# Selecting previously unselected package libjack0:amd64.
# (Reading database ... 122787 files and directories currently installed.)
# Preparing to unpack .../00-libjack0_1%3a0.126.0-2build3_amd64.deb ...
# Unpacking libjack0:amd64 (1:0.126.0-2build3) ...
# Selecting previously unselected package libibus-1.0-5:amd64.
# Preparing to unpack .../01-libibus-1.0-5_1.5.29-2_amd64.deb ...
# Unpacking libibus-1.0-5:amd64 (1.5.29-2) ...
# Selecting previously unselected package gir1.2-ibus-1.0:amd64.
# Preparing to unpack .../02-gir1.2-ibus-1.0_1.5.29-2_amd64.deb ...
# Unpacking gir1.2-ibus-1.0:amd64 (1.5.29-2) ...
# Selecting previously unselected package javascript-common.
# Preparing to unpack .../03-javascript-common_11+nmu1_all.deb ...
# Unpacking javascript-common (11+nmu1) ...
# Selecting previously unselected package libasound2-dev:amd64.
# Preparing to unpack .../04-libasound2-dev_1.2.11-1ubuntu0.3_amd64.deb ...
# Unpacking libasound2-dev:amd64 (1.2.11-1ubuntu0.3) ...
# Selecting previously unselected package libavutil-dev:amd64.
# Preparing to unpack .../05-libavutil-dev_7%3a6.1.1-3ubuntu5_amd64.deb ...
# Unpacking libavutil-dev:amd64 (7:6.1.1-3ubuntu5) ...
# Selecting previously unselected package libswresample-dev:amd64.
# Preparing to unpack .../06-libswresample-dev_7%3a6.1.1-3ubuntu5_amd64.deb ...
# Unpacking libswresample-dev:amd64 (7:6.1.1-3ubuntu5) ...
# Selecting previously unselected package libavcodec-dev:amd64.
# Preparing to unpack .../07-libavcodec-dev_7%3a6.1.1-3ubuntu5_amd64.deb ...
# Unpacking libavcodec-dev:amd64 (7:6.1.1-3ubuntu5) ...
# Selecting previously unselected package libavformat-dev:amd64.
# Preparing to unpack .../08-libavformat-dev_7%3a6.1.1-3ubuntu5_amd64.deb ...
# Unpacking libavformat-dev:amd64 (7:6.1.1-3ubuntu5) ...
# Selecting previously unselected package libdbus-1-dev:amd64.
# Preparing to unpack .../09-libdbus-1-dev_1.14.10-4ubuntu4.1_amd64.deb ...
# Unpacking libdbus-1-dev:amd64 (1.14.10-4ubuntu4.1) ...
# Selecting previously unselected package libwayland-server0:amd64.
# Preparing to unpack .../10-libwayland-server0_1.22.0-2.1build1_amd64.deb ...
# Unpacking libwayland-server0:amd64 (1.22.0-2.1build1) ...
# Selecting previously unselected package libwayland-bin.
# Preparing to unpack .../11-libwayland-bin_1.22.0-2.1build1_amd64.deb ...
# Unpacking libwayland-bin (1.22.0-2.1build1) ...
# Selecting previously unselected package libwayland-dev:amd64.
# Preparing to unpack .../12-libwayland-dev_1.22.0-2.1build1_amd64.deb ...
# Unpacking libwayland-dev:amd64 (1.22.0-2.1build1) ...
# Selecting previously unselected package libdecor-0-dev:amd64.
# Preparing to unpack .../13-libdecor-0-dev_0.2.2-1build2_amd64.deb ...
# Unpacking libdecor-0-dev:amd64 (0.2.2-1build2) ...
# Selecting previously unselected package libdrm-radeon1:amd64.
# Preparing to unpack .../14-libdrm-radeon1_2.4.125-1ubuntu0.1~24.04.2_amd64.deb ...
# Unpacking libdrm-radeon1:amd64 (2.4.125-1ubuntu0.1~24.04.2) ...
# Selecting previously unselected package libdrm-nouveau2:amd64.
# Preparing to unpack .../15-libdrm-nouveau2_2.4.125-1ubuntu0.1~24.04.2_amd64.deb ...
# Unpacking libdrm-nouveau2:amd64 (2.4.125-1ubuntu0.1~24.04.2) ...
# Selecting previously unselected package libpciaccess-dev:amd64.
# Preparing to unpack .../16-libpciaccess-dev_0.17-3ubuntu0.24.04.2_amd64.deb ...
# Unpacking libpciaccess-dev:amd64 (0.17-3ubuntu0.24.04.2) ...
# Selecting previously unselected package libdrm-dev:amd64.
# Preparing to unpack .../17-libdrm-dev_2.4.125-1ubuntu0.1~24.04.2_amd64.deb ...
# Unpacking libdrm-dev:amd64 (2.4.125-1ubuntu0.1~24.04.2) ...
# Selecting previously unselected package libglx-dev:amd64.
# Preparing to unpack .../18-libglx-dev_1.7.0-1build1_amd64.deb ...
# Unpacking libglx-dev:amd64 (1.7.0-1build1) ...
# Selecting previously unselected package libgl-dev:amd64.
# Preparing to unpack .../19-libgl-dev_1.7.0-1build1_amd64.deb ...
# Unpacking libgl-dev:amd64 (1.7.0-1build1) ...
# Selecting previously unselected package libegl-dev:amd64.
# Preparing to unpack .../20-libegl-dev_1.7.0-1build1_amd64.deb ...
# Unpacking libegl-dev:amd64 (1.7.0-1build1) ...
# Selecting previously unselected package libinstpatch-1.0-2:amd64.
# Preparing to unpack .../21-libinstpatch-1.0-2_1.1.6-1build2_amd64.deb ...
# Unpacking libinstpatch-1.0-2:amd64 (1.1.6-1build2) ...
# Selecting previously unselected package libwebrtc-audio-processing1:amd64.
# Preparing to unpack .../22-libwebrtc-audio-processing1_0.3.1-0ubuntu6_amd64.deb ...
# Unpacking libwebrtc-audio-processing1:amd64 (0.3.1-0ubuntu6) ...
# Selecting previously unselected package libspa-0.2-modules:amd64.
# Preparing to unpack .../23-libspa-0.2-modules_1.0.5-1ubuntu3.3_amd64.deb ...
# Unpacking libspa-0.2-modules:amd64 (1.0.5-1ubuntu3.3) ...
# Selecting previously unselected package libpipewire-0.3-0t64:amd64.
# Preparing to unpack .../24-libpipewire-0.3-0t64_1.0.5-1ubuntu3.3_amd64.deb ...
# Unpacking libpipewire-0.3-0t64:amd64 (1.0.5-1ubuntu3.3) ...
# Selecting previously unselected package timgm6mb-soundfont.
# Preparing to unpack .../25-timgm6mb-soundfont_1.3-5_all.deb ...
# Unpacking timgm6mb-soundfont (1.3-5) ...
# Selecting previously unselected package libfluidsynth3:amd64.
# Preparing to unpack .../26-libfluidsynth3_2.3.4-1build3_amd64.deb ...
# Unpacking libfluidsynth3:amd64 (2.3.4-1build3) ...
# Selecting previously unselected package libinstpatch-dev:amd64.
# Preparing to unpack .../27-libinstpatch-dev_1.1.6-1build2_amd64.deb ...
# Unpacking libinstpatch-dev:amd64 (1.1.6-1build2) ...
# Selecting previously unselected package libjack-dev:amd64.
# Preparing to unpack .../28-libjack-dev_1%3a0.126.0-2build3_amd64.deb ...
# Unpacking libjack-dev:amd64 (1:0.126.0-2build3) ...
# Selecting previously unselected package libspa-0.2-dev:amd64.
# Preparing to unpack .../29-libspa-0.2-dev_1.0.5-1ubuntu3.3_amd64.deb ...
# Unpacking libspa-0.2-dev:amd64 (1.0.5-1ubuntu3.3) ...
# Selecting previously unselected package libpipewire-0.3-dev:amd64.
# Preparing to unpack .../30-libpipewire-0.3-dev_1.0.5-1ubuntu3.3_amd64.deb ...
# Unpacking libpipewire-0.3-dev:amd64 (1.0.5-1ubuntu3.3) ...
# Selecting previously unselected package libpulse-mainloop-glib0:amd64.
# Preparing to unpack .../31-libpulse-mainloop-glib0_1%3a16.1+dfsg1-2ubuntu10.1_amd64.deb ...
# Unpacking libpulse-mainloop-glib0:amd64 (1:16.1+dfsg1-2ubuntu10.1) ...
# Selecting previously unselected package libpulse-dev:amd64.
# Preparing to unpack .../32-libpulse-dev_1%3a16.1+dfsg1-2ubuntu10.1_amd64.deb ...
# Unpacking libpulse-dev:amd64 (1:16.1+dfsg1-2ubuntu10.1) ...
# Selecting previously unselected package libgbm-dev:amd64.
# Preparing to unpack .../33-libgbm-dev_25.2.8-0ubuntu0.24.04.2_amd64.deb ...
# Unpacking libgbm-dev:amd64 (25.2.8-0ubuntu0.24.04.2) ...
# Selecting previously unselected package libgles1:amd64.
# Preparing to unpack .../34-libgles1_1.7.0-1build1_amd64.deb ...
# Unpacking libgles1:amd64 (1.7.0-1build1) ...
# Selecting previously unselected package libgles-dev:amd64.
# Preparing to unpack .../35-libgles-dev_1.7.0-1build1_amd64.deb ...
# Unpacking libgles-dev:amd64 (1.7.0-1build1) ...
# Selecting previously unselected package libibus-1.0-dev:amd64.
# Preparing to unpack .../36-libibus-1.0-dev_1.5.29-2_amd64.deb ...
# Unpacking libibus-1.0-dev:amd64 (1.5.29-2) ...
# Selecting previously unselected package libsamplerate0-dev:amd64.
# Preparing to unpack .../37-libsamplerate0-dev_0.2.2-4build1_amd64.deb ...
# Unpacking libsamplerate0-dev:amd64 (0.2.2-4build1) ...
# Selecting previously unselected package libsndio-dev:amd64.
# Preparing to unpack .../38-libsndio-dev_1.9.0-0.3build3_amd64.deb ...
# Unpacking libsndio-dev:amd64 (1.9.0-0.3build3) ...
# Selecting previously unselected package libudev-dev:amd64.
# Preparing to unpack .../39-libudev-dev_255.4-1ubuntu8.17_amd64.deb ...
# Unpacking libudev-dev:amd64 (255.4-1ubuntu8.17) ...
# Selecting previously unselected package libxfixes-dev:amd64.
# Preparing to unpack .../40-libxfixes-dev_1%3a6.0.0-2build1_amd64.deb ...
# Unpacking libxfixes-dev:amd64 (1:6.0.0-2build1) ...
# Selecting previously unselected package libxcursor-dev:amd64.
# Preparing to unpack .../41-libxcursor-dev_1%3a1.2.1-1build1_amd64.deb ...
# Unpacking libxcursor-dev:amd64 (1:1.2.1-1build1) ...
# Selecting previously unselected package libxi-dev:amd64.
# Preparing to unpack .../42-libxi-dev_2%3a1.8.1-1build1_amd64.deb ...
# Unpacking libxi-dev:amd64 (2:1.8.1-1build1) ...
# Selecting previously unselected package libxinerama-dev:amd64.
# Preparing to unpack .../43-libxinerama-dev_2%3a1.1.4-3build1_amd64.deb ...
# Unpacking libxinerama-dev:amd64 (2:1.1.4-3build1) ...
# Selecting previously unselected package libxkbcommon-dev:amd64.
# Preparing to unpack .../44-libxkbcommon-dev_1.6.0-1build1_amd64.deb ...
# Unpacking libxkbcommon-dev:amd64 (1.6.0-1build1) ...
# Selecting previously unselected package libxrandr-dev:amd64.
# Preparing to unpack .../45-libxrandr-dev_2%3a1.5.2-2build1_amd64.deb ...
# Unpacking libxrandr-dev:amd64 (2:1.5.2-2build1) ...
# Selecting previously unselected package libxt-dev:amd64.
# Preparing to unpack .../46-libxt-dev_1%3a1.2.1-1.2build1_amd64.deb ...
# Unpacking libxt-dev:amd64 (1:1.2.1-1.2build1) ...
# Selecting previously unselected package libxv-dev:amd64.
# Preparing to unpack .../47-libxv-dev_2%3a1.0.11-1.1build1_amd64.deb ...
# Unpacking libxv-dev:amd64 (2:1.0.11-1.1build1) ...
# Selecting previously unselected package libxxf86vm-dev:amd64.
# Preparing to unpack .../48-libxxf86vm-dev_1%3a1.1.4-1build4_amd64.deb ...
# Unpacking libxxf86vm-dev:amd64 (1:1.1.4-1build4) ...
# Selecting previously unselected package libsdl2-dev:amd64.
# Preparing to unpack .../49-libsdl2-dev_2.30.0+dfsg-1ubuntu3.1_amd64.deb ...
# Unpacking libsdl2-dev:amd64 (2.30.0+dfsg-1ubuntu3.1) ...
# Selecting previously unselected package libsystemd-dev:amd64.
# Preparing to unpack .../50-libsystemd-dev_255.4-1ubuntu8.17_amd64.deb ...
# Unpacking libsystemd-dev:amd64 (255.4-1ubuntu8.17) ...
# Selecting previously unselected package libfluidsynth-dev:amd64.
# Preparing to unpack .../51-libfluidsynth-dev_2.3.4-1build3_amd64.deb ...
# Unpacking libfluidsynth-dev:amd64 (2.3.4-1build3) ...
# Selecting previously unselected package libgraphite2-dev:amd64.
# Preparing to unpack .../52-libgraphite2-dev_1.3.14-2ubuntu0.24.04.1_amd64.deb ...
# Unpacking libgraphite2-dev:amd64 (1.3.14-2ubuntu0.24.04.1) ...
# Selecting previously unselected package libharfbuzz-cairo0:amd64.
# Preparing to unpack .../53-libharfbuzz-cairo0_8.3.0-2build2_amd64.deb ...
# Unpacking libharfbuzz-cairo0:amd64 (8.3.0-2build2) ...
# Selecting previously unselected package libharfbuzz-icu0:amd64.
# Preparing to unpack .../54-libharfbuzz-icu0_8.3.0-2build2_amd64.deb ...
# Unpacking libharfbuzz-icu0:amd64 (8.3.0-2build2) ...
# Selecting previously unselected package libharfbuzz-subset0:amd64.
# Preparing to unpack .../55-libharfbuzz-subset0_8.3.0-2build2_amd64.deb ...
# Unpacking libharfbuzz-subset0:amd64 (8.3.0-2build2) ...
# Selecting previously unselected package libharfbuzz-dev:amd64.
# Preparing to unpack .../56-libharfbuzz-dev_8.3.0-2build2_amd64.deb ...
# Unpacking libharfbuzz-dev:amd64 (8.3.0-2build2) ...
# Selecting previously unselected package libjs-underscore.
# Preparing to unpack .../57-libjs-underscore_1.13.4~dfsg+~1.11.4-3_all.deb ...
# Unpacking libjs-underscore (1.13.4~dfsg+~1.11.4-3) ...
# Selecting previously unselected package libjs-sphinxdoc.
# Preparing to unpack .../58-libjs-sphinxdoc_7.2.6-6_all.deb ...
# Unpacking libjs-sphinxdoc (7.2.6-6) ...
# Selecting previously unselected package libmodplug1:amd64.
# Preparing to unpack .../59-libmodplug1_1%3a0.8.9.0-3build1_amd64.deb ...
# Unpacking libmodplug1:amd64 (1:0.8.9.0-3build1) ...
# Selecting previously unselected package libmodplug-dev:amd64.
# Preparing to unpack .../60-libmodplug-dev_1%3a0.8.9.0-3build1_amd64.deb ...
# Unpacking libmodplug-dev:amd64 (1:0.8.9.0-3build1) ...
# Selecting previously unselected package libopusfile0:amd64.
# Preparing to unpack .../61-libopusfile0_0.12-4build3_amd64.deb ...
# Unpacking libopusfile0:amd64 (0.12-4build3) ...
# Selecting previously unselected package libopusfile-dev:amd64.
# Preparing to unpack .../62-libopusfile-dev_0.12-4build3_amd64.deb ...
# Unpacking libopusfile-dev:amd64 (0.12-4build3) ...
# Selecting previously unselected package libpipewire-0.3-common.
# Preparing to unpack .../63-libpipewire-0.3-common_1.0.5-1ubuntu3.3_all.deb ...
# Unpacking libpipewire-0.3-common (1.0.5-1ubuntu3.3) ...
# Selecting previously unselected package libportmidi0:amd64.
# Preparing to unpack .../64-libportmidi0_1%3a217-6.1build3_amd64.deb ...
# Unpacking libportmidi0:amd64 (1:217-6.1build3) ...
# Selecting previously unselected package libportmidi-dev.
# Preparing to unpack .../65-libportmidi-dev_1%3a217-6.1build3_amd64.deb ...
# Unpacking libportmidi-dev (1:217-6.1build3) ...
# Selecting previously unselected package libsdl2-image-2.0-0:amd64.
# Preparing to unpack .../66-libsdl2-image-2.0-0_2.8.2+dfsg-1build2_amd64.deb ...
# Unpacking libsdl2-image-2.0-0:amd64 (2.8.2+dfsg-1build2) ...
# Selecting previously unselected package libsdl2-image-dev:amd64.
# Preparing to unpack .../67-libsdl2-image-dev_2.8.2+dfsg-1build2_amd64.deb ...
# Unpacking libsdl2-image-dev:amd64 (2.8.2+dfsg-1build2) ...
# Selecting previously unselected package libsdl2-mixer-2.0-0:amd64.
# Preparing to unpack .../68-libsdl2-mixer-2.0-0_2.8.0+dfsg-1build3_amd64.deb ...
# Unpacking libsdl2-mixer-2.0-0:amd64 (2.8.0+dfsg-1build3) ...
# Selecting previously unselected package libsdl2-mixer-dev:amd64.
# Preparing to unpack .../69-libsdl2-mixer-dev_2.8.0+dfsg-1build3_amd64.deb ...
# Unpacking libsdl2-mixer-dev:amd64 (2.8.0+dfsg-1build3) ...
# Selecting previously unselected package libsdl2-ttf-2.0-0:amd64.
# Preparing to unpack .../70-libsdl2-ttf-2.0-0_2.22.0+dfsg-1_amd64.deb ...
# Unpacking libsdl2-ttf-2.0-0:amd64 (2.22.0+dfsg-1) ...
# Selecting previously unselected package libsdl2-ttf-dev:amd64.
# Preparing to unpack .../71-libsdl2-ttf-dev_2.22.0+dfsg-1_amd64.deb ...
# Unpacking libsdl2-ttf-dev:amd64 (2.22.0+dfsg-1) ...
# Selecting previously unselected package libswscale-dev:amd64.
# Preparing to unpack .../72-libswscale-dev_7%3a6.1.1-3ubuntu5_amd64.deb ...
# Unpacking libswscale-dev:amd64 (7:6.1.1-3ubuntu5) ...
# Selecting previously unselected package python3.12-dev.
# Preparing to unpack .../73-python3.12-dev_3.12.3-1ubuntu0.16_amd64.deb ...
# Unpacking python3.12-dev (3.12.3-1ubuntu0.16) ...
# Selecting previously unselected package python3-dev.
# Preparing to unpack .../74-python3-dev_3.12.3-0ubuntu2.1_amd64.deb ...
# Unpacking python3-dev (3.12.3-0ubuntu2.1) ...
# Selecting previously unselected package python3-wheel.
# Preparing to unpack .../75-python3-wheel_0.42.0-2_all.deb ...
# Unpacking python3-wheel (0.42.0-2) ...
# Selecting previously unselected package python3-pip.
# Preparing to unpack .../76-python3-pip_24.0+dfsg-1ubuntu1.3_all.deb ...
# Unpacking python3-pip (24.0+dfsg-1ubuntu1.3) ...
# Setting up libsdl2-image-2.0-0:amd64 (2.8.2+dfsg-1build2) ...
# Setting up libpipewire-0.3-common (1.0.5-1ubuntu3.3) ...
# Setting up libavutil-dev:amd64 (7:6.1.1-3ubuntu5) ...
# Setting up javascript-common (11+nmu1) ...
# Setting up libmodplug1:amd64 (1:0.8.9.0-3build1) ...
# Setting up libwayland-server0:amd64 (1.22.0-2.1build1) ...
# Setting up libmodplug-dev:amd64 (1:0.8.9.0-3build1) ...
# Setting up libdrm-nouveau2:amd64 (2.4.125-1ubuntu0.1~24.04.2) ...
# Setting up libsndio-dev:amd64 (1.9.0-0.3build3) ...
# Setting up libharfbuzz-icu0:amd64 (8.3.0-2build2) ...
# Setting up libpciaccess-dev:amd64 (0.17-3ubuntu0.24.04.2) ...
# Setting up libswresample-dev:amd64 (7:6.1.1-3ubuntu5) ...
# Setting up libdrm-radeon1:amd64 (2.4.125-1ubuntu0.1~24.04.2) ...
# Setting up libavcodec-dev:amd64 (7:6.1.1-3ubuntu5) ...
# Setting up libxxf86vm-dev:amd64 (1:1.1.4-1build4) ...
# Setting up libxkbcommon-dev:amd64 (1.6.0-1build1) ...
# Setting up libsamplerate0-dev:amd64 (0.2.2-4build1) ...
# Setting up libibus-1.0-5:amd64 (1.5.29-2) ...
# Setting up libwebrtc-audio-processing1:amd64 (0.3.1-0ubuntu6) ...
# Setting up libavformat-dev:amd64 (7:6.1.1-3ubuntu5) ...
# Setting up python3-wheel (0.42.0-2) ...
# Setting up libgbm-dev:amd64 (25.2.8-0ubuntu0.24.04.2) ...
# Setting up libxfixes-dev:amd64 (1:6.0.0-2build1) ...
# Setting up libxv-dev:amd64 (2:1.0.11-1.1build1) ...
# Setting up libwayland-bin (1.22.0-2.1build1) ...
# Setting up libgraphite2-dev:amd64 (1.3.14-2ubuntu0.24.04.1) ...
# Setting up libxrandr-dev:amd64 (2:1.5.2-2build1) ...
# Setting up libharfbuzz-cairo0:amd64 (8.3.0-2build2) ...
# Setting up libdbus-1-dev:amd64 (1.14.10-4ubuntu4.1) ...
# Setting up libspa-0.2-modules:amd64 (1.0.5-1ubuntu3.3) ...
# Setting up libxt-dev:amd64 (1:1.2.1-1.2build1) ...
# Setting up libjack0:amd64 (1:0.126.0-2build3) ...
# Setting up libpulse-mainloop-glib0:amd64 (1:16.1+dfsg1-2ubuntu10.1) ...
# Setting up libgles1:amd64 (1.7.0-1build1) ...
# Setting up libswscale-dev:amd64 (7:6.1.1-3ubuntu5) ...
# Setting up libportmidi0:amd64 (1:217-6.1build3) ...
# Setting up python3.12-dev (3.12.3-1ubuntu0.16) ...
# Setting up libudev-dev:amd64 (255.4-1ubuntu8.17) ...
# Setting up libxinerama-dev:amd64 (2:1.1.4-3build1) ...
# Setting up python3-pip (24.0+dfsg-1ubuntu1.3) ...
# Setting up libpulse-dev:amd64 (1:16.1+dfsg1-2ubuntu10.1) ...
# Setting up libportmidi-dev (1:217-6.1build3) ...
# Setting up libharfbuzz-subset0:amd64 (8.3.0-2build2) ...
# Setting up libglx-dev:amd64 (1.7.0-1build1) ...
# Setting up libsdl2-ttf-2.0-0:amd64 (2.22.0+dfsg-1) ...
# Setting up libjack-dev:amd64 (1:0.126.0-2build3) ...
# Setting up libxi-dev:amd64 (2:1.8.1-1build1) ...
# Setting up libspa-0.2-dev:amd64 (1.0.5-1ubuntu3.3) ...
# Setting up libasound2-dev:amd64 (1.2.11-1ubuntu0.3) ...
# Setting up timgm6mb-soundfont (1.3-5) ...
# update-alternatives: using /usr/share/sounds/sf2/TimGM6mb.sf2 to provide /usr/share/sounds/sf2/default-GM.sf2 (default-GM.sf2) in auto mode
# update-alternatives: using /usr/share/sounds/sf2/TimGM6mb.sf2 to provide /usr/share/sounds/sf3/default-GM.sf3 (default-GM.sf3) in auto mode
# Setting up gir1.2-ibus-1.0:amd64 (1.5.29-2) ...
# Setting up libopusfile0:amd64 (0.12-4build3) ...
# Setting up libpipewire-0.3-0t64:amd64 (1.0.5-1ubuntu3.3) ...
# Setting up libinstpatch-1.0-2:amd64 (1.1.6-1build2) ...
# Setting up libgl-dev:amd64 (1.7.0-1build1) ...
# Setting up libsystemd-dev:amd64 (255.4-1ubuntu8.17) ...
# Setting up libfluidsynth3:amd64 (2.3.4-1build3) ...
# Setting up libjs-underscore (1.13.4~dfsg+~1.11.4-3) ...
# Setting up libharfbuzz-dev:amd64 (8.3.0-2build2) ...
# Setting up libdrm-dev:amd64 (2.4.125-1ubuntu0.1~24.04.2) ...
# Setting up libegl-dev:amd64 (1.7.0-1build1) ...
# Setting up libxcursor-dev:amd64 (1:1.2.1-1build1) ...
# Setting up libopusfile-dev:amd64 (0.12-4build3) ...
# Setting up libwayland-dev:amd64 (1.22.0-2.1build1) ...
# Setting up libdecor-0-dev:amd64 (0.2.2-1build2) ...
# Setting up libsdl2-mixer-2.0-0:amd64 (2.8.0+dfsg-1build3) ...
# Setting up libjs-sphinxdoc (7.2.6-6) ...
# Setting up libpipewire-0.3-dev:amd64 (1.0.5-1ubuntu3.3) ...
# Setting up libgles-dev:amd64 (1.7.0-1build1) ...
# Setting up libinstpatch-dev:amd64 (1.1.6-1build2) ...
# Setting up python3-dev (3.12.3-0ubuntu2.1) ...
# Processing triggers for sgml-base (1.31) ...
# Processing triggers for libc-bin (2.39-0ubuntu8.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.1 is not a symbolic link
#
# Processing triggers for man-db (2.12.0-4build2) ...
# Setting up libibus-1.0-dev:amd64 (1.5.29-2) ...
# Setting up libsdl2-dev:amd64 (2.30.0+dfsg-1ubuntu3.1) ...
# Setting up libfluidsynth-dev:amd64 (2.3.4-1build3) ...
# Setting up libsdl2-ttf-dev:amd64 (2.22.0+dfsg-1) ...
# Setting up libsdl2-mixer-dev:amd64 (2.8.0+dfsg-1build3) ...
# Setting up libsdl2-image-dev:amd64 (2.8.2+dfsg-1build2) ...

# %%
# !sudo apt-get install -y \
    libgstreamer1.0 \
    gstreamer1.0-plugins-base \
    gstreamer1.0-plugins-good
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Note, selecting 'libgstreamer1.0-dev' for regex 'libgstreamer1.0'
# Note, selecting 'libgstreamer1.0-0' for regex 'libgstreamer1.0'
# libgstreamer1.0-0 is already the newest version (1.24.2-1ubuntu0.1).
# libgstreamer1.0-0 set to manually installed.
# The following additional packages will be installed:
#   gir1.2-gstreamer-1.0 glib-networking glib-networking-common
#   glib-networking-services gsettings-desktop-schemas gstreamer1.0-x libaa1
#   libcdparanoia0 libdv4t64 libdw-dev libelf-dev libgstreamer-plugins-base1.0-0
#   libgstreamer-plugins-good1.0-0 libgudev-1.0-0 liborc-0.4-0t64 libproxy1v5
#   libshout3 libsoup-3.0-0 libsoup-3.0-common libtag1v5 libtag1v5-vanilla
#   libunwind-dev libv4l-0t64 libv4lconvert0t64 libvisual-0.4-0 libwavpack1
#   libxtst6 session-migration
# Suggested packages:
#   gvfs libdv-bin oss-compat libvisual-0.4-plugins gstreamer1.0-doc
# The following NEW packages will be installed:
#   gir1.2-gstreamer-1.0 glib-networking glib-networking-common
#   glib-networking-services gsettings-desktop-schemas gstreamer1.0-plugins-base
#   gstreamer1.0-plugins-good gstreamer1.0-x libaa1 libcdparanoia0 libdv4t64
#   libdw-dev libelf-dev libgstreamer-plugins-base1.0-0
#   libgstreamer-plugins-good1.0-0 libgstreamer1.0-dev libgudev-1.0-0
#   liborc-0.4-0t64 libproxy1v5 libshout3 libsoup-3.0-0 libsoup-3.0-common
#   libtag1v5 libtag1v5-vanilla libunwind-dev libv4l-0t64 libv4lconvert0t64
#   libvisual-0.4-0 libwavpack1 libxtst6 session-migration
# 0 upgraded, 31 newly installed, 0 to remove and 11 not upgraded.
# Need to get 8,443 kB of archives.
# After this operation, 34.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 gir1.2-gstreamer-1.0 amd64 1.24.2-1ubuntu0.1 [88.4 kB]
# Get:2 http://archive.ubuntu.com/ubuntu noble/main amd64 libproxy1v5 amd64 0.5.4-4build1 [26.5 kB]
# Get:3 http://archive.ubuntu.com/ubuntu noble/main amd64 glib-networking-common all 2.80.0-1build1 [6,702 B]
# Get:4 http://archive.ubuntu.com/ubuntu noble/main amd64 glib-networking-services amd64 2.80.0-1build1 [12.8 kB]
# Get:5 http://archive.ubuntu.com/ubuntu noble/main amd64 session-migration amd64 0.3.9build1 [9,034 B]
# Get:6 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 gsettings-desktop-schemas all 46.1-0ubuntu1 [35.6 kB]
# Get:7 http://archive.ubuntu.com/ubuntu noble/main amd64 glib-networking amd64 2.80.0-1build1 [64.1 kB]
# Get:8 http://archive.ubuntu.com/ubuntu noble/main amd64 libcdparanoia0 amd64 3.10.2+debian-14build3 [48.5 kB]
# Get:9 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 liborc-0.4-0t64 amd64 1:0.4.38-1ubuntu0.1 [207 kB]
# Get:10 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libgstreamer-plugins-base1.0-0 amd64 1.24.2-1ubuntu0.4 [862 kB]
# Get:11 http://archive.ubuntu.com/ubuntu noble/main amd64 libvisual-0.4-0 amd64 0.4.2-2build1 [115 kB]
# Get:12 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 gstreamer1.0-plugins-base amd64 1.24.2-1ubuntu0.4 [721 kB]
# Get:13 http://archive.ubuntu.com/ubuntu noble/main amd64 libaa1 amd64 1.4p5-51.1 [49.9 kB]
# Get:14 http://archive.ubuntu.com/ubuntu noble/main amd64 libdv4t64 amd64 1.0.0-17.1build1 [63.2 kB]
# Get:15 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libgstreamer-plugins-good1.0-0 amd64 1.24.2-1ubuntu1.5 [33.5 kB]
# Get:16 http://archive.ubuntu.com/ubuntu noble/main amd64 libgudev-1.0-0 amd64 1:238-5ubuntu1 [15.9 kB]
# Get:17 http://archive.ubuntu.com/ubuntu noble/main amd64 libshout3 amd64 2.4.6-1build2 [50.3 kB]
# Get:18 http://archive.ubuntu.com/ubuntu noble/main amd64 libtag1v5-vanilla amd64 1.13.1-1build1 [326 kB]
# Get:19 http://archive.ubuntu.com/ubuntu noble/main amd64 libtag1v5 amd64 1.13.1-1build1 [11.7 kB]
# Get:20 http://archive.ubuntu.com/ubuntu noble/main amd64 libv4lconvert0t64 amd64 1.26.1-4build3 [87.6 kB]
# Get:21 http://archive.ubuntu.com/ubuntu noble/main amd64 libv4l-0t64 amd64 1.26.1-4build3 [46.9 kB]
# Get:22 http://archive.ubuntu.com/ubuntu noble/main amd64 libwavpack1 amd64 5.6.0-1build1 [84.6 kB]
# Get:23 http://archive.ubuntu.com/ubuntu noble/main amd64 libxtst6 amd64 2:1.2.3-1.1build1 [12.6 kB]
# Get:24 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libsoup-3.0-common all 3.4.4-5ubuntu0.7 [11.6 kB]
# Get:25 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libsoup-3.0-0 amd64 3.4.4-5ubuntu0.7 [292 kB]
# Get:26 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 gstreamer1.0-plugins-good amd64 1.24.2-1ubuntu1.5 [2,236 kB]
# Get:27 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 gstreamer1.0-x amd64 1.24.2-1ubuntu0.4 [85.0 kB]
# Get:28 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libelf-dev amd64 0.190-1.1ubuntu0.1 [68.5 kB]
# Get:29 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libdw-dev amd64 0.190-1.1ubuntu0.1 [340 kB]
# Get:30 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libunwind-dev amd64 1.6.2-3build1.1 [1,906 kB]
# Get:31 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libgstreamer1.0-dev amd64 1.24.2-1ubuntu0.1 [525 kB]
# Fetched 8,443 kB in 1s (6,423 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 79, <STDIN> line 31.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package gir1.2-gstreamer-1.0:amd64.
# (Reading database ... 126516 files and directories currently installed.)
# Preparing to unpack .../00-gir1.2-gstreamer-1.0_1.24.2-1ubuntu0.1_amd64.deb ...
# Unpacking gir1.2-gstreamer-1.0:amd64 (1.24.2-1ubuntu0.1) ...
# Selecting previously unselected package libproxy1v5:amd64.
# Preparing to unpack .../01-libproxy1v5_0.5.4-4build1_amd64.deb ...
# Unpacking libproxy1v5:amd64 (0.5.4-4build1) ...
# Selecting previously unselected package glib-networking-common.
# Preparing to unpack .../02-glib-networking-common_2.80.0-1build1_all.deb ...
# Unpacking glib-networking-common (2.80.0-1build1) ...
# Selecting previously unselected package glib-networking-services.
# Preparing to unpack .../03-glib-networking-services_2.80.0-1build1_amd64.deb ...
# Unpacking glib-networking-services (2.80.0-1build1) ...
# Selecting previously unselected package session-migration.
# Preparing to unpack .../04-session-migration_0.3.9build1_amd64.deb ...
# Unpacking session-migration (0.3.9build1) ...
# Selecting previously unselected package gsettings-desktop-schemas.
# Preparing to unpack .../05-gsettings-desktop-schemas_46.1-0ubuntu1_all.deb ...
# Unpacking gsettings-desktop-schemas (46.1-0ubuntu1) ...
# Selecting previously unselected package glib-networking:amd64.
# Preparing to unpack .../06-glib-networking_2.80.0-1build1_amd64.deb ...
# Unpacking glib-networking:amd64 (2.80.0-1build1) ...
# Selecting previously unselected package libcdparanoia0:amd64.
# Preparing to unpack .../07-libcdparanoia0_3.10.2+debian-14build3_amd64.deb ...
# Unpacking libcdparanoia0:amd64 (3.10.2+debian-14build3) ...
# Selecting previously unselected package liborc-0.4-0t64:amd64.
# Preparing to unpack .../08-liborc-0.4-0t64_1%3a0.4.38-1ubuntu0.1_amd64.deb ...
# Unpacking liborc-0.4-0t64:amd64 (1:0.4.38-1ubuntu0.1) ...
# Selecting previously unselected package libgstreamer-plugins-base1.0-0:amd64.
# Preparing to unpack .../09-libgstreamer-plugins-base1.0-0_1.24.2-1ubuntu0.4_amd64.deb ...
# Unpacking libgstreamer-plugins-base1.0-0:amd64 (1.24.2-1ubuntu0.4) ...
# Selecting previously unselected package libvisual-0.4-0:amd64.
# Preparing to unpack .../10-libvisual-0.4-0_0.4.2-2build1_amd64.deb ...
# Unpacking libvisual-0.4-0:amd64 (0.4.2-2build1) ...
# Selecting previously unselected package gstreamer1.0-plugins-base:amd64.
# Preparing to unpack .../11-gstreamer1.0-plugins-base_1.24.2-1ubuntu0.4_amd64.deb ...
# Unpacking gstreamer1.0-plugins-base:amd64 (1.24.2-1ubuntu0.4) ...
# Selecting previously unselected package libaa1:amd64.
# Preparing to unpack .../12-libaa1_1.4p5-51.1_amd64.deb ...
# Unpacking libaa1:amd64 (1.4p5-51.1) ...
# Selecting previously unselected package libdv4t64:amd64.
# Preparing to unpack .../13-libdv4t64_1.0.0-17.1build1_amd64.deb ...
# Unpacking libdv4t64:amd64 (1.0.0-17.1build1) ...
# Selecting previously unselected package libgstreamer-plugins-good1.0-0:amd64.
# Preparing to unpack .../14-libgstreamer-plugins-good1.0-0_1.24.2-1ubuntu1.5_amd64.deb ...
# Unpacking libgstreamer-plugins-good1.0-0:amd64 (1.24.2-1ubuntu1.5) ...
# Selecting previously unselected package libgudev-1.0-0:amd64.
# Preparing to unpack .../15-libgudev-1.0-0_1%3a238-5ubuntu1_amd64.deb ...
# Unpacking libgudev-1.0-0:amd64 (1:238-5ubuntu1) ...
# Selecting previously unselected package libshout3:amd64.
# Preparing to unpack .../16-libshout3_2.4.6-1build2_amd64.deb ...
# Unpacking libshout3:amd64 (2.4.6-1build2) ...
# Selecting previously unselected package libtag1v5-vanilla:amd64.
# Preparing to unpack .../17-libtag1v5-vanilla_1.13.1-1build1_amd64.deb ...
# Unpacking libtag1v5-vanilla:amd64 (1.13.1-1build1) ...
# Selecting previously unselected package libtag1v5:amd64.
# Preparing to unpack .../18-libtag1v5_1.13.1-1build1_amd64.deb ...
# Unpacking libtag1v5:amd64 (1.13.1-1build1) ...
# Selecting previously unselected package libv4lconvert0t64:amd64.
# Preparing to unpack .../19-libv4lconvert0t64_1.26.1-4build3_amd64.deb ...
# Unpacking libv4lconvert0t64:amd64 (1.26.1-4build3) ...
# Selecting previously unselected package libv4l-0t64:amd64.
# Preparing to unpack .../20-libv4l-0t64_1.26.1-4build3_amd64.deb ...
# Unpacking libv4l-0t64:amd64 (1.26.1-4build3) ...
# Selecting previously unselected package libwavpack1:amd64.
# Preparing to unpack .../21-libwavpack1_5.6.0-1build1_amd64.deb ...
# Unpacking libwavpack1:amd64 (5.6.0-1build1) ...
# Selecting previously unselected package libxtst6:amd64.
# Preparing to unpack .../22-libxtst6_2%3a1.2.3-1.1build1_amd64.deb ...
# Unpacking libxtst6:amd64 (2:1.2.3-1.1build1) ...
# Selecting previously unselected package libsoup-3.0-common.
# Preparing to unpack .../23-libsoup-3.0-common_3.4.4-5ubuntu0.7_all.deb ...
# Unpacking libsoup-3.0-common (3.4.4-5ubuntu0.7) ...
# Selecting previously unselected package libsoup-3.0-0:amd64.
# Preparing to unpack .../24-libsoup-3.0-0_3.4.4-5ubuntu0.7_amd64.deb ...
# Unpacking libsoup-3.0-0:amd64 (3.4.4-5ubuntu0.7) ...
# Selecting previously unselected package gstreamer1.0-plugins-good:amd64.
# Preparing to unpack .../25-gstreamer1.0-plugins-good_1.24.2-1ubuntu1.5_amd64.deb ...
# Unpacking gstreamer1.0-plugins-good:amd64 (1.24.2-1ubuntu1.5) ...
# Selecting previously unselected package gstreamer1.0-x:amd64.
# Preparing to unpack .../26-gstreamer1.0-x_1.24.2-1ubuntu0.4_amd64.deb ...
# Unpacking gstreamer1.0-x:amd64 (1.24.2-1ubuntu0.4) ...
# Selecting previously unselected package libelf-dev:amd64.
# Preparing to unpack .../27-libelf-dev_0.190-1.1ubuntu0.1_amd64.deb ...
# Unpacking libelf-dev:amd64 (0.190-1.1ubuntu0.1) ...
# Selecting previously unselected package libdw-dev:amd64.
# Preparing to unpack .../28-libdw-dev_0.190-1.1ubuntu0.1_amd64.deb ...
# Unpacking libdw-dev:amd64 (0.190-1.1ubuntu0.1) ...
# Selecting previously unselected package libunwind-dev:amd64.
# Preparing to unpack .../29-libunwind-dev_1.6.2-3build1.1_amd64.deb ...
# Unpacking libunwind-dev:amd64 (1.6.2-3build1.1) ...
# Selecting previously unselected package libgstreamer1.0-dev:amd64.
# Preparing to unpack .../30-libgstreamer1.0-dev_1.24.2-1ubuntu0.1_amd64.deb ...
# Unpacking libgstreamer1.0-dev:amd64 (1.24.2-1ubuntu0.1) ...
# Setting up libcdparanoia0:amd64 (3.10.2+debian-14build3) ...
# Setting up gir1.2-gstreamer-1.0:amd64 (1.24.2-1ubuntu0.1) ...
# Setting up session-migration (0.3.9build1) ...
# Created symlink /etc/systemd/user/graphical-session-pre.target.wants/session-migration.service → /usr/lib/systemd/user/session-migration.service.
# Setting up libproxy1v5:amd64 (0.5.4-4build1) ...
# Setting up libtag1v5-vanilla:amd64 (1.13.1-1build1) ...
# Setting up libunwind-dev:amd64 (1.6.2-3build1.1) ...
# Setting up libv4lconvert0t64:amd64 (1.26.1-4build3) ...
# Setting up libvisual-0.4-0:amd64 (0.4.2-2build1) ...
# Setting up libxtst6:amd64 (2:1.2.3-1.1build1) ...
# Setting up libsoup-3.0-common (3.4.4-5ubuntu0.7) ...
# Setting up liborc-0.4-0t64:amd64 (1:0.4.38-1ubuntu0.1) ...
# Setting up libshout3:amd64 (2.4.6-1build2) ...
# Setting up libelf-dev:amd64 (0.190-1.1ubuntu0.1) ...
# Setting up libdv4t64:amd64 (1.0.0-17.1build1) ...
# Setting up libv4l-0t64:amd64 (1.26.1-4build3) ...
# Setting up libtag1v5:amd64 (1.13.1-1build1) ...
# Setting up libwavpack1:amd64 (5.6.0-1build1) ...
# Setting up glib-networking-common (2.80.0-1build1) ...
# Setting up libgudev-1.0-0:amd64 (1:238-5ubuntu1) ...
# Setting up libaa1:amd64 (1.4p5-51.1) ...
# Setting up gsettings-desktop-schemas (46.1-0ubuntu1) ...
# Setting up glib-networking-services (2.80.0-1build1) ...
# Setting up libgstreamer-plugins-base1.0-0:amd64 (1.24.2-1ubuntu0.4) ...
# Setting up libdw-dev:amd64 (0.190-1.1ubuntu0.1) ...
# Setting up libgstreamer-plugins-good1.0-0:amd64 (1.24.2-1ubuntu1.5) ...
# Setting up gstreamer1.0-plugins-base:amd64 (1.24.2-1ubuntu0.4) ...
# Setting up gstreamer1.0-x:amd64 (1.24.2-1ubuntu0.4) ...
# Setting up libgstreamer1.0-dev:amd64 (1.24.2-1ubuntu0.1) ...
# Processing triggers for libc-bin (2.39-0ubuntu8.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.1 is not a symbolic link
#
# Processing triggers for man-db (2.12.0-4build2) ...
# Processing triggers for libglib2.0-0t64:amd64 (2.80.0-6ubuntu3.8) ...
# Setting up glib-networking:amd64 (2.80.0-1build1) ...
# Setting up libsoup-3.0-0:amd64 (3.4.4-5ubuntu0.7) ...
# Setting up gstreamer1.0-plugins-good:amd64 (1.24.2-1ubuntu1.5) ...
# Processing triggers for libc-bin (2.39-0ubuntu8.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.1 is not a symbolic link

# %%
# !sudo apt-get install build-essential libsqlite3-dev sqlite3 bzip2 libbz2-dev zlib1g-dev libssl-dev openssl libgdbm-dev libgdbm-compat-dev liblzma-dev libreadline-dev libncursesw5-dev libffi-dev uuid-dev libffi6
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Note, selecting 'libncurses-dev' instead of 'libncursesw5-dev'
# E: Unable to locate package libffi6

# %%
# !sudo apt-get install libffi-dev
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libffi-dev is already the newest version (3.4.6-1build1).
# libffi-dev set to manually installed.
# 0 upgraded, 0 newly installed, 0 to remove and 11 not upgraded.

# %%
# !buildozer init
# Out:
# Buildozer is running as root!
# This is not recommended, and may lead to problems later.
# Are you sure you want to continue [y/n]? y
# # Copy /usr/local/lib/python3.13/dist-packages/buildozer/default.spec to buildozer.spec
# File buildozer.spec created, ready to customize!

# %%
# !buildozer -v android debug
# Out:
# Buildozer is running as root!
# This is not recommended, and may lead to problems later.
# Are you sure you want to continue [y/n]? y
# # Ensure build layout
# # Check configuration tokens
# # Preparing build
# # Check requirements for android
# # Search for Git (git)
# #  -> found at /usr/bin/git
# # Search for Cython (cython)
# #  -> found at /usr/local/bin/cython
# # Search for Java compiler (javac)
# #  -> found at /usr/bin/javac
# # Search for Java keytool (keytool)
# #  -> found at /usr/bin/keytool
# # Install platform
# # Run 'git config --get remote.origin.url' ...
# # Cwd /content/.buildozer/android/platform/python-for-android
# https://github.com/kivy/python-for-android.git
# # Run 'git branch -vv' ...
# # Cwd /content/.buildozer/android/platform/python-for-android
# * master 58d21141 [origin/master] Merge pull request #3321 from kivy/release-2026.05.09
# # Run '/usr/bin/python3 -m pip install -q --user appdirs colorama>=0.3.3 jinja2 sh>=2, <3.0; sys_platform!="win32" meson ninja build toml packaging setuptools wheel~=0.43.0' ...
# # Cwd None
# # Apache ANT found at /root/.buildozer/android/platform/apache-ant-1.9.4
# # Android SDK found at /root/.buildozer/android/platform/android-sdk
# # Recommended android's NDK version by p4a is: 28c
# # Android NDK found at /root/.buildozer/android/platform/android-ndk-r28c
# # Run '/usr/bin/python3 -m pythonforandroid.toolchain aab -h --color=always --storage-dir=/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a --ndk-api=24 --ignore-setup-py --debug' ...
# # Cwd /content/.buildozer/android/platform/python-for-android
# # Check application requirements
# # Compile platform
# # Run '/usr/bin/python3 -m pythonforandroid.toolchain create --dist_name=myapp --bootstrap=sdl2 --requirements=python3==3.11.9,hostpython3==3.11.9,kivy==2.3.1,kivymd==2.0.0,PyPDF2==3.0.1 --arch=arm64-v8a --arch=armeabi-v7a --copy-libs --color=always --storage-dir=/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a --ndk-api=24 --ignore-setup-py --debug' ...
# # Cwd /content/.buildozer/android/platform/python-for-android
# [WARNING]: prerequisites.py is experimental and does not support all prerequisites yet.
# [WARNING]: Please report any issues to the python-for-android issue tracker.
# [WARNING]: prerequisites.py is experimental and does not support all prerequisites yet.
# [WARNING]: Please report any issues to the python-for-android issue tracker.
# [INFO]:    Recipe python3: version "3.11.9" requested
# [INFO]:    Recipe hostpython3: version "3.11.9" requested
# [INFO]:    Recipe kivy: version "2.3.1" requested
# [INFO]:    Recipe kivymd: version "2.0.0" requested
# [INFO]:    Recipe PyPDF2: version "3.0.1" requested
# [INFO]:    Will compile for the following archs: arm64-v8a, armeabi-v7a
# [DEBUG]:   Create directory /content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/dists
# [DEBUG]:   Create directory /content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/bootstrap_builds
# [DEBUG]:   Create directory /content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/other_builds
# [INFO]:    Found Android API target in $ANDROIDAPI: 33
# [INFO]:    Available Android APIs are (33)
# [INFO]:    Requested API target 33 is available, continuing.
# [INFO]:    Found NDK dir in $ANDROIDNDK: /root/.buildozer/android/platform/android-ndk-r28c
# [INFO]:    Found NDK version 28c
# [WARNING]: Maximum recommended NDK version is 28c, but newer versions may work.
# [WARNING]: Newer NDKs may not be fully supported by p4a.
# [INFO]:    Getting NDK API version (i.e. minimum supported API) from user argument
# [INFO]:    ccache is missing, the build will not be optimized in the future.
# [DEBUG]:   All possible dists: []
# [DEBUG]:   Dist matching name and arch: []
# [DEBUG]:   Dist matching ndk_api and recipe: []
# [INFO]:    No existing dists meet the given requirements!
# [INFO]:    No dist exists that meets your requirements, so one will be built.
# [INFO]:    Found a single valid recipe set: ['hostpython3', 'kivymd', 'libffi', 'openssl', 'pypdf2', 'sdl2_image', 'sdl2_mixer', 'sdl2_ttf', 'six', 'sqlite3', 'python3', 'sdl2', 'pyjnius', 'setuptools', 'android', 'kivy']
# [INFO]:    The selected bootstrap is sdl2
# [INFO]:    # Creating dist with sdl2 bootstrap
# [INFO]:    Dist will have name myapp and requirements (python3, hostpython3, kivy, kivymd, PyPDF2)
# [INFO]:    Dist contains the following requirements as recipes: ['hostpython3', 'libffi', 'openssl', 'sdl2_image', 'sdl2_mixer', 'sdl2_ttf', 'sqlite3', 'python3', 'sdl2', 'pyjnius', 'setuptools', 'android', 'kivy']
# [INFO]:    Dist will also contain modules (certifi, idna, requests, chardet, six, filetype, kivymd, urllib3, pypdf2) installed from pip
# [INFO]:    Dist will be build in mode debug
# [INFO]:    -> directory context /content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/bootstrap_builds/sdl2
# [INFO]:    <- directory context /content/.buildozer/android/platform/python-for-android
# [DEBUG]:   Create directory /content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/dists/myapp
# [INFO]:    Recipe build order is ['hostpython3', 'libffi', 'openssl', 'sdl2_image', 'sdl2_mixer', 'sdl2_ttf', 'sqlite3', 'python3', 'sdl2', 'pyjnius', 'setuptools', 'android', 'kivy']
# [INFO]:    The requirements (certifi, chardet, filetype, idna, kivymd, pypdf2, requests, six, urllib3) were not found as recipes, they will be installed with pip.
# [INFO]:    # Downloading recipes
# [INFO]:    Downloading hostpython3
# [DEBUG]:   Create directory /content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/packages/hostpython3
# [INFO]:    -> directory context /content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/packages/hostpython3
# [DEBUG]:   -> running basename https://github.com/python/cpython/archive/refs/tags/v3.11.9.tar.gz
# [DEBUG]:   	v3.11.9.tar.gz
# [DEBUG]:   Downloading hostpython3 from https://github.com/python/cpython/archive/refs/tags/v3.11.9.tar.gz
# [DEBUG]:   -> running rm -f .mark-v3.11.9.tar.gz
# [INFO]:    Downloading hostpython3 from https://github.com/python/cpython/archive/refs/tags/v3.11.9.tar.gz
# [INFO]:    <- directory context /content/.buildozer/android/platform/python-for-android
# [INFO]:    Downloading libffi
# [DEBUG]:   Create directory /content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/packages/libffi
# [INFO]:    -> directory context /content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/packages/libffi
# [DEBUG]:   -> running basename https://github.com/libffi/libffi/archive/v3.4.2.tar.gz
# [DEBUG]:   	v3.4.2.tar.gz
# [DEBUG]:   Downloading libffi from https://github.com/libffi/libffi/archive/v3.4.2.tar.gz
# [DEBUG]:   -> running rm -f .mark-v3.4.2.tar.gz
# [INFO]:    Downloading libffi from https://github.com/libffi/libffi/archive/v3.4.2.tar.gz
# [INFO]:    <- directory context /content/.buildozer/android/platform/python-for-android
# [INFO]:    Downloading openssl
# [DEBUG]:   Create directory /content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/packages/openssl
# [INFO]:    -> directory context /content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/packages/openssl
# [DEBUG]:   -> running basename https://www.openssl.org/source/openssl-3.3.1.tar.gz
# [DEBUG]:   	openssl-3.3.1.tar.gz
# [DEBUG]:   Downloading openssl from https://www.openssl.org/source/openssl-3.3.1.tar.gz
# [DEBUG]:   -> running rm -f .mark-openssl-3.3.1.tar.gz
# [INFO]:    Downloading openssl from https://www.openssl.org/source/openssl-3.3.1.tar.gz
# [INFO]:    <- directory context /content/.buildozer/android/platform/python-for-android
# [INFO]:    Downloading sdl2_image
# [DEBUG]:   Create directory /content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/packages/sdl2_image
# [INFO]:    -> directory context /content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/packages/sdl2_image
# [DEBUG]:   -> running basename https://github.com/libsdl-org/SDL_image/releases/download/release-2.8.2/SDL2_image-2.8.2.tar.gz
# [DEBUG]:   	SDL2_image-2.8.2.tar.gz
# [DEBUG]:   Downloading sdl2_image from https://github.com/libsdl-org/SDL_image/releases/download/release-2.8.2/SDL2_image-2.8.2.tar.gz
# [DEBUG]:   -> running rm -f .mark-SDL2_image-2.8.2.tar.gz
# [INFO]:    Downloading sdl2_image from https://github.com/libsdl-org/SDL_image/releases/download/release-2.8.2/SDL2_image-2.8.2.tar.gz
# [INFO]:    <- directory context /content/.buildozer/android/platform/python-for-android
# [INFO]:    Downloading sdl2_mixer
# [DEBUG]:   Create directory /content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/packages/sdl2_mixer
# [INFO]:    -> directory context /content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/packages/sdl2_mixer
# [DEBUG]:   -> running basename https://github.com/libsdl-org/SDL_mixer/releases/download/release-2.6.3/SDL2_mixer-2.6.3.tar.gz
# [DEBUG]:   	SDL2_mixer-2.6.3.tar.gz
# [DEBUG]:   Downloading sdl2_mixer from https://github.com/libsdl-org/SDL_mixer/releases/download/release-2.6.3/SDL2_mixer-2.6.3.tar.gz
# [DEBUG]:   -> running rm -f .mark-SDL2_mixer-2.6.3.tar.gz
# [INFO]:    Downloading sdl2_mixer from https://github.com/libsdl-org/SDL_mixer/releases/download/release-2.6.3/SDL2_mixer-2.6.3.tar.gz
# [INFO]:    <- directory context /content/.buildozer/android/platform/python-for-android
# [INFO]:    Downloading sdl2_ttf
# [DEBUG]:   Create directory /content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/packages/sdl2_ttf
# [INFO]:    -> directory context /content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/packages/sdl2_ttf
# [DEBUG]:   -> running basename https://github.com/libsdl-org/SDL_ttf/releases/download/release-2.22.0/SDL2_ttf-2.22.0.tar.gz
# [DEBUG]:   	SDL2_ttf-2.22.0.tar.gz
# [DEBUG]:   Downloading sdl2_ttf from https://github.com/libsdl-org/SDL_ttf/releases/download/release-2.22.0/SDL2_ttf-2.22.0.tar.gz
# [DEBUG]:   -> running rm -f .mark-SDL2_ttf-2.22.0.tar.gz
# [INFO]:    Downloading sdl2_ttf from https://github.com/libsdl-org/SDL_ttf/releases/download/release-2.22.0/SDL2_ttf-2.22.0.tar.gz
# [INFO]:    <- directory context /content/.buildozer/android/platform/python-for-android
# [INFO]:    Downloading sqlite3
# [DEBUG]:   Create directory /content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/packages/sqlite3
# [INFO]:    -> directory context /content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/packages/sqlite3
# [DEBUG]:   -> running basename https://github.com/sqlite/sqlite/archive/refs/tags/version-3.50.4.tar.gz
# [DEBUG]:   	version-3.50.4.tar.gz
# [DEBUG]:   Downloading sqlite3 from https://github.com/sqlite/sqlite/archive/refs/tags/version-3.50.4.tar.gz
# [DEBUG]:   -> running rm -f .mark-version-3.50.4.tar.gz
# [INFO]:    Downloading sqlite3 from https://github.com/sqlite/sqlite/archive/refs/tags/version-3.50.4.tar.gz
# [INFO]:    <- directory context /content/.buildozer/android/platform/python-for-android
# [INFO]:    Downloading python3
# [DEBUG]:   Create directory /content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/packages/python3
# [INFO]:    -> directory context /content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/packages/python3
# [DEBUG]:   -> running basename https://github.com/python/cpython/archive/refs/tags/v3.11.9.tar.gz
# [DEBUG]:   	v3.11.9.tar.gz
# [DEBUG]:   Downloading python3 from https://github.com/python/cpython/archive/refs/tags/v3.11.9.tar.gz
# [DEBUG]:   -> running rm -f .mark-v3.11.9.tar.gz
# [INFO]:    Downloading python3 from https://github.com/python/cpython/archive/refs/tags/v3.11.9.tar.gz
# [INFO]:    <- directory context /content/.buildozer/android/platform/python-for-android
# [INFO]:    Downloading sdl2
# [DEBUG]:   Create directory /content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/packages/sdl2
# [INFO]:    -> directory context /content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/packages/sdl2
# [DEBUG]:   -> running basename https://github.com/libsdl-org/SDL/releases/download/release-2.30.11/SDL2-2.30.11.tar.gz
# [DEBUG]:   	SDL2-2.30.11.tar.gz
# [DEBUG]:   Downloading sdl2 from https://github.com/libsdl-org/SDL/releases/download/release-2.30.11/SDL2-2.30.11.tar.gz
# [DEBUG]:   -> running rm -f .mark-SDL2-2.30.11.tar.gz
# [INFO]:    Downloading sdl2 from https://github.com/libsdl-org/SDL/releases/download/release-2.30.11/SDL2-2.30.11.tar.gz
# [INFO]:    <- directory context /content/.buildozer/android/platform/python-for-android
# [INFO]:    Downloading pyjnius
# [DEBUG]:   Create directory /content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/packages/pyjnius
# [INFO]:    -> directory context /content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/packages/pyjnius
# [DEBUG]:   -> running basename https://github.com/kivy/pyjnius/archive/1.7.0.zip
# [DEBUG]:   	1.7.0.zip
# [DEBUG]:   Downloading pyjnius from https://github.com/kivy/pyjnius/archive/1.7.0.zip
# [DEBUG]:   -> running rm -f .mark-1.7.0.zip
# [INFO]:    Downloading pyjnius from https://github.com/kivy/pyjnius/archive/1.7.0.zip
# [INFO]:    <- directory context /content/.buildozer/android/platform/python-for-android
# [INFO]:    Downloading setuptools
# [INFO]:    Skipping setuptools download as no URL is set
# [INFO]:    Downloading android
# [INFO]:    Skipping android download as no URL is set
# [INFO]:    Downloading kivy
# [DEBUG]:   Create directory /content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/packages/kivy
# [INFO]:    -> directory context /content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/packages/kivy
# [DEBUG]:   -> running basename https://github.com/kivy/kivy/archive/2.3.1.zip
# [DEBUG]:   	2.3.1.zip
# [DEBUG]:   Downloading kivy from https://github.com/kivy/kivy/archive/2.3.1.zip
# [DEBUG]:   -> running rm -f .mark-2.3.1.zip
# [INFO]:    Downloading kivy from https://github.com/kivy/kivy/archive/2.3.1.zip
# [INFO]:    <- directory context /content/.buildozer/android/platform/python-for-android
# [INFO]:    # Building all recipes for arch arm64-v8a
# [INFO]:    # Unpacking recipes
# [DEBUG]:   Create directory /content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/other_builds/hostpython3/desktop
# [INFO]:    Unpacking hostpython3 for arm64-v8a
# [DEBUG]:   -> running basename https://github.com/python/cpython/archive/refs/tags/v3.11.9.tar.gz
# [DEBUG]:   	v3.11.9.tar.gz
# [INFO]:    -> directory context /content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/other_builds/hostpython3/desktop
# [DEBUG]:   Moving cpython-3.11.9 to /content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/other_builds/hostpython3/desktop/hostpython3
# [INFO]:    <- directory context /content/.buildozer/android/platform/python-for-android
# [DEBUG]:   Create directory /content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/other_builds/libffi/arm64-v8a__ndk_target_24
# [INFO]:    Unpacking libffi for arm64-v8a
# [DEBUG]:   -> running basename https://github.com/libffi/libffi/archive/v3.4.2.tar.gz
# [DEBUG]:   	v3.4.2.tar.gz
# [INFO]:    -> directory context /content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/other_builds/libffi/arm64-v8a__ndk_target_24
# [DEBUG]:   Moving libffi-3.4.2 to /content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/other_builds/libffi/arm64-v8a__ndk_target_24/libffi
# [INFO]:    <- directory context /content/.buildozer/android/platform/python-for-android
# [DEBUG]:   Create directory /content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/other_builds/openssl/arm64-v8a__ndk_target_24
# [INFO]:    Unpacking openssl for arm64-v8a
# [DEBUG]:   -> running basename https://www.openssl.org/source/openssl-3.3.1.tar.gz
# [DEBUG]:   	openssl-3.3.1.tar.gz
# [INFO]:    -> directory context /content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/other_builds/openssl/arm64-v8a__ndk_target_24
# [DEBUG]:   Moving openssl-3.3.1 to /content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/other_builds/openssl/arm64-v8a__ndk_target_24/openssl3
# [INFO]:    <- directory context /content/.buildozer/android/platform/python-for-android
# [INFO]:    Unpacking sdl2_image for arm64-v8a
# [DEBUG]:   -> running basename https://github.com/libsdl-org/SDL_image/releases/download/release-2.8.2/SDL2_image-2.8.2.tar.gz
# [DEBUG]:   	SDL2_image-2.8.2.tar.gz
# [INFO]:    -> directory context /content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/bootstrap_builds/sdl2/jni
# [DEBUG]:   Moving SDL2_image-2.8.2 to /content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/bootstrap_builds/sdl2/jni/SDL2_image
# [INFO]:    <- directory context /content/.buildozer/android/platform/python-for-android
# [INFO]:    Unpacking sdl2_mixer for arm64-v8a
# [DEBUG]:   -> running basename https://github.com/libsdl-org/SDL_mixer/releases/download/release-2.6.3/SDL2_mixer-2.6.3.tar.gz
# [DEBUG]:   	SDL2_mixer-2.6.3.tar.gz
# [INFO]:    -> directory context /content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/bootstrap_builds/sdl2/jni
# [DEBUG]:   Moving SDL2_mixer-2.6.3 to /content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/bootstrap_builds/sdl2/jni/SDL2_mixer
# [INFO]:    <- directory context /content/.buildozer/android/platform/python-for-android
# [INFO]:    Unpacking sdl2_ttf for arm64-v8a
# [DEBUG]:   -> running basename https://github.com/libsdl-org/SDL_ttf/releases/download/release-2.22.0/SDL2_ttf-2.22.0.tar.gz
# [DEBUG]:   	SDL2_ttf-2.22.0.tar.gz
# [INFO]:    -> directory context /content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/bootstrap_builds/sdl2/jni
# [DEBUG]:   Moving SDL2_ttf-2.22.0 to /content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/bootstrap_builds/sdl2/jni/SDL2_ttf
# [INFO]:    <- directory context /content/.buildozer/android/platform/python-for-android
# [DEBUG]:   Create directory /content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/other_builds/sqlite3/arm64-v8a__ndk_target_24
# [INFO]:    Unpacking sqlite3 for arm64-v8a
# [DEBUG]:   -> running basename https://github.com/sqlite/sqlite/archive/refs/tags/version-3.50.4.tar.gz
# [DEBUG]:   	version-3.50.4.tar.gz
# [INFO]:    -> directory context /content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/other_builds/sqlite3/arm64-v8a__ndk_target_24

# %%
# !buildozer android clean
# Out:
# Buildozer is running as root!
# This is not recommended, and may lead to problems later.
# Are you sure you want to continue [y/n]? y
# # Ensure build layout
# # Check configuration tokens
# # Run '/usr/bin/python3 -m pythonforandroid.toolchain clean_builds --color=always --storage-dir=/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a --ndk-api=24 --ignore-setup-py --debug' ...
# # Cwd /content/.buildozer/android/platform/python-for-android
# [WARNING]: prerequisites.py is experimental and does not support all prerequisites yet.
# [WARNING]: Please report any issues to the python-for-android issue tracker.
# [WARNING]: prerequisites.py is experimental and does not support all prerequisites yet.
# [WARNING]: Please report any issues to the python-for-android issue tracker.
# [DEBUG]:   Remove directory and subdirectory /content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build
# [DEBUG]:   Create directory /content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs
# [DEBUG]:   Remove directory and subdirectory /content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs
# # Run '/usr/bin/python3 -m pythonforandroid.toolchain clean_dists --color=always --storage-dir=/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a --ndk-api=24 --ignore-setup-py --debug' ...
# # Cwd /content/.buildozer/android/platform/python-for-android
# [WARNING]: prerequisites.py is experimental and does not support all prerequisites yet.
# [WARNING]: Please report any issues to the python-for-android issue tracker.
# [WARNING]: prerequisites.py is experimental and does not support all prerequisites yet.
# [WARNING]: Please report any issues to the python-for-android issue tracker.
# [DEBUG]:   Remove directory and subdirectory /content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/dists
